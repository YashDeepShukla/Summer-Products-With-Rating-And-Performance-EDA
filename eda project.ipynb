# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Why this project?
# Domain idea?
# Why this dataset?
# What will be the outcome of this project?

# %% [markdown]
# # Summer Products With Rating And Performance

# %% [markdown]
# #### - This dataset is from Kaggel.
# #### - It contains information related to the sales of summer cloths in relation to their rating.
# #### - From this we might be able to find ways to increase sales.

# %%
df = pd.read_csv('summer-products-with-rating-and-performance_2020-08.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2  2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3  Hot Summer Cool T-shirt pour les femmes Mode T...
# 4  Femmes Shorts d'été à lacets taille élastique ...
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2  2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4  Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR         100               0    3.76            54
# ...

# %%
df.drop('product_url', inplace=True, axis=1)

# %%
df.drop('product_picture', inplace=True, axis=1)

# %%
df.drop('merchant_profile_picture', inplace=True, axis=1)

# %%
df.drop('merchant_has_profile_picture', inplace=True, axis=1)

# %%
#df.drop('merchant_profile_picture', inplace=True, axis=1)

#why isn't this one working?

# %%
df.drop('merchant_info_subtitle', inplace=True, axis=1)

# %%
df.drop('merchant_id', inplace=True, axis=1)

# %%
df.drop('product_id', inplace=True, axis=1)

# %% [markdown]
# #### Since the currency_buyer, origin_country, theme and crawl_month is same for every product we can remove them and they are not of any use to us right now.

# %%
df.drop('currency_buyer', inplace=True, axis=1)

# %%
df.drop('origin_country', inplace=True, axis=1)

# %%
df.drop('theme', inplace=True, axis=1)

# %%
df.drop('crawl_month', inplace=True, axis=1)

# %%
df.head(2)
# Out:
#                                                title  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress    8.0            22
#
#    units_sold  uses_ad_boosts  rating  rating_count  rating_five_count  \
# 0         100               0    3.76            54               26.0
# 1       20000               1    3.45          6135             2269.0
#
#    rating_four_count  ...  shipping_option_price  shipping_is_express  \
# 0                8.0  ...                      4                    0
# 1             1027.0  ...                      2                    0
#
#    countries_shipped_to  inventory_total  has_urgency_banner  \
# 0                    34               50                 1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   title                        1573 non-null   object
#  1   title_orig                   1573 non-null   object
#  2   price                        1573 non-null   float64
#  3   retail_price                 1573 non-null   int64
#  4   units_sold                   1573 non-null   int64
#  5   uses_ad_boosts               1573 non-null   int64
#  6   rating                       1573 non-null   float64
#  7   rating_count                 1573 non-null   int64
#  8   rating_five_count            1528 non-null   float64
#  9   rating_four_count            1528 non-null   float64
#  10  rating_three_count           1528 non-null   float64
#  11  rating_two_count             1528 non-null   float64
#  12  rating_one_count             1528 non-null   float64
# ...

# %%
df.drop('rating_five_count', inplace=True, axis=1)

# %%
df.drop('rating_four_count', inplace=True, axis=1)

# %%
df.drop('rating_three_count', inplace=True, axis=1)

# %%
df.drop('rating_two_count', inplace=True, axis=1)

# %%
df.drop('rating_one_count', inplace=True, axis=1)

# %% [markdown]
# ###### Removing the merchant name because it contains three null values and almost every other 'merchant name' matches with the 'merchant title'.

# %%
df.drop('merchant_name', inplace=True, axis=1)

# %% [markdown]
# ##### Removing the title as we already have title_orig which is the same thing just in French.

# %%
df.drop('title', inplace=True, axis=1)

# %%
df.head()
# Out:
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2  2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4  Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#    units_sold  uses_ad_boosts  rating  rating_count  badges_count  \
# 0         100               0    3.76            54             0
# 1       20000               1    3.45          6135             0
# 2         100               0    3.57            14             0
# 3        5000               1    4.03           579             0
# 4         100               1    3.10            20             0
#
#    badge_local_product  badge_product_quality  ...  shipping_option_name  \
# ...

# %%
df.badges_count.notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1568    True
# 1569    True
# 1570    True
# 1571    True
# 1572    True
# Name: badges_count, Length: 1573, dtype: bool

# %%
#df.values()

# %%
df.urgency_text.value_counts(normalize=True).plot.pie()
# Out:
# <AxesSubplot:ylabel='urgency_text'>

# %%
df.shipping_is_express.describe()
# Out:
# count    1573.000000
# mean        0.002543
# std         0.050379
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: shipping_is_express, dtype: float64

# %% [markdown]
# ##### Calculating count, mean, std, min, 25%, 50%, 75%, max values for each column.

# %%
df.describe()
# Out:
#              price  retail_price     units_sold  uses_ad_boosts       rating  \
# count  1573.000000   1573.000000    1573.000000     1573.000000  1573.000000
# mean      8.325372     23.288620    4339.005086        0.432931     3.820896
# std       3.932030     30.357863    9356.539302        0.495639     0.515374
# min       1.000000      1.000000       1.000000        0.000000     1.000000
# 25%       5.810000      7.000000     100.000000        0.000000     3.550000
# 50%       8.000000     10.000000    1000.000000        0.000000     3.850000
# 75%      11.000000     26.000000    5000.000000        1.000000     4.110000
# max      49.000000    252.000000  100000.000000        1.000000     5.000000
#
#        rating_count  badges_count  badge_local_product  badge_product_quality  \
# count   1573.000000   1573.000000          1573.000000            1573.000000
# mean     889.659250      0.105531             0.018436               0.074380
# ...

# %%
round(df.describe())
# Out:
#         price  retail_price  units_sold  uses_ad_boosts  rating  rating_count  \
# count  1573.0        1573.0      1573.0          1573.0  1573.0        1573.0
# mean      8.0          23.0      4339.0             0.0     4.0         890.0
# std       4.0          30.0      9357.0             0.0     1.0        1984.0
# min       1.0           1.0         1.0             0.0     1.0           0.0
# 25%       6.0           7.0       100.0             0.0     4.0          24.0
# 50%       8.0          10.0      1000.0             0.0     4.0         150.0
# 75%      11.0          26.0      5000.0             1.0     4.0         855.0
# max      49.0         252.0    100000.0             1.0     5.0       20744.0
#
#        badges_count  badge_local_product  badge_product_quality  \
# count        1573.0               1573.0                 1573.0
# mean            0.0                  0.0                    0.0
# std             0.0                  0.0                    0.0
# ...

# %%
df["price"].plot.hist(bins=100, figsize=(15,5))
plt.suptitle("price",fontsize=20)
# Out:
# Text(0.5, 0.98, 'price')

# %%
sns.boxplot(x = "retail_price", y = "units_sold", data = df)
# Out:
# <AxesSubplot:xlabel='retail_price', ylabel='units_sold'>

# %%
print("Box Plot for Ratings ")
plt.boxplot(df.rating)
plt.show()
# Out:
# Box Plot for Ratings

# %%
df['product_variation_size_id'].value_counts()
# Out:
# S                      641
# XS                     356
# M                      200
# XXS                    100
# L                       49
#                       ...
# 6XL                      1
# AU plug Low quality      1
# XXXL                     1
# 25-S                     1
# SIZE S                   1
# Name: product_variation_size_id, Length: 106, dtype: int64

# %%
def ordinal_encoding(df, column, ordering):
    return df[column].apply(lambda x: ordering.index(x) if x in ordering else None)

# %%
df['product_variation_size_id']
# Out:
# 0             M
# 1            XS
# 2            XS
# 3             M
# 4             S
#          ...
# 1568          S
# 1569          S
# 1570     SIZE S
# 1571    Size S.
# 1572          S
# Name: product_variation_size_id, Length: 1573, dtype: object

# %%
df['product_color'].unique()
# Out:
# array(['white', 'green', 'leopardprint', 'black', 'yellow', 'navyblue',
#        'blue', 'beige', 'grey', 'lightblue', 'orange', 'red', 'Black',
#        'armygreen', nan, 'pink', 'khaki', 'red & blue', 'blue & pink',
#        'RED', 'white & green', 'winered', 'black & green', 'purple',
#        'whitefloral', 'floral', 'fluorescentgreen', 'orange & camouflage',
#        'lightyellow', 'coolblack', 'multicolor', 'camouflage',
#        'lightpink', 'pink & black', 'silver', 'Army green', 'lightgreen',
#        'mintgreen', 'pink & grey', 'gray', 'coffee', 'rose',
#        'light green', 'leopard', 'black & white', 'orange-red',
#        'dustypink', 'White', 'star', 'white & black', 'apricot',
#        'skyblue', 'burgundy', 'claret', 'pink & white', 'rosered', 'tan',
#        'navy blue', 'wine red', 'lightred', 'Pink', 'coralred', 'brown',
#        'lakeblue', 'darkblue', 'camel', 'pink & blue', 'nude', 'Blue',
#        'lightpurple', 'army', 'black & stripe', 'Rose red',
# ...

# %% [markdown]
# # Conclusion
# I can conclude from this dataset that the price of most things is about 8 eur, while the retail price is 23 eur. Other data I could see in this dataset is the rating, which, most of them are between 3.5 and 4.5. I noticed that most of the products are black and white, as well as that the most popular sizes are S, XS and M. Something that was very expected and that did not surprise me was to see that most of the clothes come from China, but I was surprised to see Venezuela in the dataset.
#
# I think that analyzing this kind of dataset is interesting but sometimes it can be overwhelming to know what to analyze without an objective, since there is a lot of data and I didn't know what to do with most of them, but I guess that with a clear objective, you can get a lot of interesting things out of it.
